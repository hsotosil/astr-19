# %% [markdown]
# Import matplotlib and numpy.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# I use numpy.random.triangular to randomly generate 1000 numbers and to form a triangular distrubtion.

# %%
#Generate 1000 random numbers with Triangular distrubtion.
x = np.random.triangular(0.5, 6, 10, 1000)

# %% [markdown]
# Histogram the random numbers into 100 bins.

# %%
#Create the histogram bins
width = 0.5
histmin = np.floor(min(x))
histmax = np.ceil(max(x))+width

bins = np.arange(histmin, histmax, width)
plt.hist(x,bins=100, alpha=0.5, edgecolor="black")
plt.ylabel("Y Axis")
plt.xlabel("X Axis")
plt.savefig("cj2-10_histogram_plot.pdf", bbox_inches="tight",facecolor="white")
